# %%
import pandas as pd

# %%
melb_df = pd.read_csv('melb_data_fe.csv')

# %%
melb_data = melb_df.copy()

# %%
melb_data.head()
# Out:
#        Suburb  Rooms   Type      Price Method SellerG        Date  Distance  \
# 0  Abbotsford      2  house  1480000.0      S  Biggin  2016-03-12       2.5
# 1  Abbotsford      2  house  1035000.0      S  Biggin  2016-04-02       2.5
# 2  Abbotsford      3  house  1465000.0     SP  Biggin  2017-04-03       2.5
# 3  Abbotsford      3  house   850000.0     PI  Biggin  2017-04-03       2.5
# 4  Abbotsford      4  house  1600000.0     VB  Nelson  2016-04-06       2.5
#
#    Postcode  Bedroom  ...  Longtitude             Regionname  Propertycount  \
# 0      3067        2  ...    144.9984  Northern Metropolitan           4019
# 1      3067        2  ...    144.9934  Northern Metropolitan           4019
# 2      3067        3  ...    144.9944  Northern Metropolitan           4019
# 3      3067        3  ...    144.9969  Northern Metropolitan           4019
# 4      3067        3  ...    144.9941  Northern Metropolitan           4019
#
# ...

# %%
melb_data.columns
# Out:
# Index(['Suburb', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Date',
#        'Distance', 'Postcode', 'Bedroom', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname',
#        'Propertycount', 'MeanRoomsSquare', 'AreaRatio', 'MonthSale',
#        'AgeBuilding', 'WeekdaySale', 'StreetType', 'Weekend'],
#       dtype='object')

# %%
melb_data['Quarter'] = pd.to_datetime(melb_data['Date']).dt.quarter

# %%
second_most_pop_quater = melb_data['Quarter'].value_counts().iloc[1]
second_most_pop_quater
# Out:
# 4359

# %%
cols_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_unique_values = 150
for col in melb_data.columns:
    if melb_data[col].nunique() < max_unique_values and col not in cols_to_exclude:
        melb_data[col] = melb_data[col].astype('category')

# %%
melb_data.sort_values(by='AreaRatio', ascending=False, ignore_index=True).iloc[1558]
# Out:
# Suburb                       Elsternwick
# Rooms                                  2
# Type                               house
# Price                           716000.0
# Method                                 S
# SellerG                    hockingstuart
# Date                          2017-03-06
# Distance                             7.2
# Postcode                            3185
# Bedroom                                2
# Bathroom                               1
# Car                                    1
# Landsize                             0.0
# BuildingArea                       126.0
# CouncilArea                    Glen Eira
# Lattitude                      -37.89438
# Longtitude                     145.00851
# Regionname         Southern Metropolitan
# Propertycount                       4898
# MeanRoomsSquare                     25.2
# AreaRatio                            1.0
# MonthSale                              3
# AgeBuilding                           47
# ...

# %%
melb_data_townhouse = melb_data[(melb_data['Type'] == 'townhouse') & (melb_data['Rooms'] > 2)]
melb_data_townhouse.sort_values(by=['Rooms', 'MeanRoomsSquare'], ascending=[True, False], ignore_index=True).iloc[18]
# Out:
# Suburb                     Brighton East
# Rooms                                  3
# Type                           townhouse
# Price                          1300000.0
# Method                                PI
# SellerG                           Buxton
# Date                          2016-09-17
# Distance                            10.7
# Postcode                            3187
# Bedroom                                3
# Bathroom                               2
# Car                                    2
# Landsize                           337.0
# BuildingArea                       222.0
# CouncilArea                      Bayside
# Lattitude                       -37.9196
# Longtitude                      145.0205
# Regionname         Southern Metropolitan
# Propertycount                       6938
# MeanRoomsSquare                    27.75
# AreaRatio                      -0.205725
# MonthSale                              9
# AgeBuilding                           16
# ...

# %%
melb_data.loc[melb_data['Rooms'] > 2]
# Out:
#              Suburb  Rooms   Type      Price Method   SellerG        Date  \
# 2        Abbotsford      3  house  1465000.0     SP    Biggin  2017-04-03
# 3        Abbotsford      3  house   850000.0     PI    Biggin  2017-04-03
# 4        Abbotsford      4  house  1600000.0     VB    Nelson  2016-04-06
# 6        Abbotsford      3  house  1876000.0      S    Nelson  2016-07-05
# 11       Abbotsford      3  house  1350000.0     VB    Nelson  2016-12-11
# ...             ...    ...    ...        ...    ...       ...         ...
# 13575         other      4  house  1245000.0      S     Barry  2017-08-26
# 13576  Williamstown      3  house  1031000.0     SP  Williams  2017-08-26
# 13577  Williamstown      3  house  1170000.0      S     Raine  2017-08-26
# 13578  Williamstown      4  house  2500000.0     PI   Sweeney  2017-08-26
# 13579    Yarraville      4  house  1285000.0     SP   Village  2017-08-26
#
#        Distance  Postcode  Bedroom  ...                  Regionname  \
# ...
